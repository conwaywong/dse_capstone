# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The following workbook assumes that the PEMs data has already been split out using the CloverETL Workspace.

# %%
# %cd ../data-out
# !ls
# Out:
# /Users/johngill/Documents/DSE/jgilliii/dse_capstone/traffic/jsg_test/data-out
# Lanes.csv        Observations.csv Stations.csv

# %% [markdown]
# ## Read in Stations and Observations

# %%
stat = pd.read_csv('Stations.csv',quotechar='"')
obso = pd.read_csv('Observations.csv')

# %% [markdown]
# ## List of 52 Eastbound Stations

# %%
fwy_id = list(stat[(stat["Fwy"] == 52) & (stat["Dir"] == "E") & (-stat["Type"].isin(['FR','OR','HV','FF']))].sort(['Abs_PM'])["ID"])
print len(fwy_id)
stat[stat["ID"].isin(fwy_id)].sort(['Abs_PM'])
# Out:
# 18
#            ID  Fwy Dir  District  County   City State_PM  Abs_PM   Latitude  \
# 778   1114136   52   E        11      73  66000       .3   0.300  32.837447
# 1043  1118557   52   E        11      73  66000    1.309   1.309  32.841394
# 773   1114108   52   E        11      73  66000    1.897   1.897  32.845413
# 1045  1118567   52   E        11      73  66000    2.218   2.218  32.846717
# 779   1114141   52   E        11      73  66000     3.15   3.150  32.846153
# 780   1114147   52   E        11      73  66000     4.65   4.650  32.841823
# 1046  1118575   52   E        11      73  66000    4.856   4.856  32.839837
# 1094  1119445   52   E        11      73  66000    5.471   5.471  32.837522
# 1049  1118624   52   E        11      73  66000    5.471   5.471  32.837522
# 781   1114153   52   E        11      73  66000    6.235   6.235  32.840091
# 1051  1118636   52   E        11      73  66000    7.245   7.245  32.841626
# 774   1114114   52   E        11      73  66000    7.299   7.299  32.841682
# 575   1111536   52   E        11      73  66000     8.71   8.710  32.841127
# 777   1114131   52   E        11      73  66000    10.05  10.050  32.847830
# 813   1114520   52   E        11      73  66000    11.55  11.550  32.853427
# 815   1114529   52   E        11      73  66000    12.45  12.450  32.851092
# 566   1111526   52   E        11      73  66000    13.36  13.360  32.843985
# 811   1114511   52   E        11      73  70224    14.25  14.250  32.835925
#
#        Longitude  Length Type  Lanes                 Name  User_ID_1  \
# 778  -117.234743   0.804   ML      3         .3 M E/O I-5       3033
# 1043 -117.218295   0.798   ML      2   52 EB @ Regents Rd      16006
# 773  -117.209402   0.455   ML      2  .6 M E/O REGENTS RD       3023
# 1045 -117.204307   0.626   ML      2    52 EB W/O Genesee      16008
# 779  -117.188480   1.216   ML      3      .53 M W/O I-805       3034
# 780  -117.164749   0.853   ML      4            E/O I-805       3035
# 1046 -117.162111   0.410   ML      4    52 EB E/O Rte 805      16104
# 1094 -117.152449   0.307   ML      3    52 EB @ Convoy St      16106
# 1049 -117.152449   0.382   ML      3    52 EB @ Convoy St      26106
# 781  -117.139742   0.887   ML      4     .37 M W/O SR-163       3036
# 1051 -117.122614   0.532   ML      3  52 EB W/OSeparation      11514
# 774  -117.121715   0.733   ML      4             W/O I-15       3024
# 575  -117.097366   1.375   ML      3     E52 W/O SANTO RD        285
# 777  -117.076315   1.420   ML      3         E/O SANTO RD       3032
# 813  -117.053258   1.200   ML      3  2.0 M W/O MAST BLVD       3037
# 815  -117.037986   0.905   ML      2  1.0 M W/O MAST BLVD       3038
# 566  -117.025934   0.900   ML      2    EB 52 @ MAST BLVD        277
# 811  -117.015497   0.968   ML      2        E/O MAST BLVD       3025
#
#       User_ID_2  User_ID_3  User_ID_4
# 778         NaN        NaN        NaN
# 1043        NaN        NaN        NaN
# 773         NaN        NaN        NaN
# 1045        NaN        NaN        NaN
# 779         NaN        NaN        NaN
# 780         NaN        NaN        NaN
# 1046        NaN        NaN        NaN
# 1094        NaN        NaN        NaN
# 1049        NaN        NaN        NaN
# 781         NaN        NaN        NaN
# 1051        NaN        NaN        NaN
# 774         NaN        NaN        NaN
# 575         NaN        NaN        NaN
# 777         NaN        NaN        NaN
# 813         NaN        NaN        NaN
# 815         NaN        NaN        NaN
# 566         NaN        NaN        NaN
# 811         NaN        NaN        NaN

# %% [markdown]
# ## Avg Speed vs Time for 52 East

# %%
for fwy in fwy_id:
    fig = obso[obso["Station"] == fwy].plot(x='Timestamp', y='Avg Speed')
    fig.set_title(str(stat[stat["ID"] == fwy]["Name"]))
    for l in fig.get_xticklabels():
        l.set_rotation(45)
